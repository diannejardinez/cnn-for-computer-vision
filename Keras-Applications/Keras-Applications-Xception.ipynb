# %% [markdown]
# #  Model: Xception

# %% [markdown]
# Source Code for Xception: Trilogy Education Services © 2019
#
# Image Source: UnSplash

# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
# Load the Xception model
# https://keras.io/api/applications/xception/
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
# Default Image Size for Xception
image_size = (299, 299)

# %%
# Prediction function using Xception model
def predict(image_path):
    """Use Xception to label image"""
    
    # Loading image for the input dimensions that Xception was trained with
    img = image.load_img(image_path, target_size=image_size)
    
    # Preprocess image for model prediction (scaling and normalization for Xception)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    # Predictions
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=5)[0])

# %%
image_path = os.path.join("Images", "image1.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02113023', 'Pembroke', 0.6999146), ('n02113186', 'Cardigan', 0.19980015), ('n02110806', 'basenji', 0.0044932337), ('n02086910', 'papillon', 0.0013348373), ('n02085620', 'Chihuahua', 0.001162443)]

# %%
image_path = os.path.join("Images", "image2.jpeg")
predict(image_path)
# Out:
# Predicted: [('n04409515', 'tennis_ball', 0.14542551), ('n02102480', 'Sussex_spaniel', 0.09673437), ('n02102040', 'English_springer', 0.09512998), ('n02102318', 'cocker_spaniel', 0.09429484), ('n02099267', 'flat-coated_retriever', 0.032108452)]

# %%
image_path = os.path.join("Images", "image3.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02510455', 'giant_panda', 0.88861084), ('n02447366', 'badger', 0.005965885), ('n02509815', 'lesser_panda', 0.003968421), ('n02132136', 'brown_bear', 0.0014825787), ('n02134084', 'ice_bear', 0.0012150207)]

# %%
image_path = os.path.join("Images", "image4.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02342885', 'hamster', 0.9066365), ('n07714990', 'broccoli', 0.003312613), ('n03794056', 'mousetrap', 0.0011723603), ('n01531178', 'goldfinch', 0.0010648067), ('n02441942', 'weasel', 0.00085002754)]

# %%
image_path = os.path.join("Images", "image5.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02346627', 'porcupine', 0.98187953), ('n02138441', 'meerkat', 0.0015285976), ('n02361337', 'marmot', 0.00023705499), ('n02120505', 'grey_fox', 0.00018123466), ('n01872401', 'echidna', 0.00018067639)]

# %%
image_path = os.path.join("Images", "image6.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02101388', 'Brittany_spaniel', 0.18853682), ('n02099267', 'flat-coated_retriever', 0.13593999), ('n02099601', 'golden_retriever', 0.10539464), ('n02102480', 'Sussex_spaniel', 0.07684599), ('n02099849', 'Chesapeake_Bay_retriever', 0.049532954)]

# %%
image_path = os.path.join("Images", "image7.jpeg")
predict(image_path)
# Out:
# Predicted: [('n01818515', 'macaw', 0.89438033), ('n01820546', 'lorikeet', 0.0018817112), ('n01819313', 'sulphur-crested_cockatoo', 0.001470331), ('n03325584', 'feather_boa', 0.0014684113), ('n01817953', 'African_grey', 0.0009791293)]

# %%
image_path = os.path.join("Images", "image8.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02123045', 'tabby', 0.46353066), ('n02123159', 'tiger_cat', 0.23944524), ('n02124075', 'Egyptian_cat', 0.08994864), ('n02127052', 'lynx', 0.006958472), ('n02128385', 'leopard', 0.0013492089)]

# %%
image_path = os.path.join("Images", "image9.jpeg")
predict(image_path)
# Out:
# Predicted: [('n01644373', 'tree_frog', 0.89046645), ('n01644900', 'tailed_frog', 0.032056257), ('n01629819', 'European_fire_salamander', 0.0014481823), ('n01641577', 'bullfrog', 0.0010836468), ('n01675722', 'banded_gecko', 0.001049959)]

# %%
image_path = os.path.join("Images", "image10.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02108915', 'French_bulldog', 0.9962716), ('n02096585', 'Boston_bull', 0.00023990904), ('n02110958', 'pug', 8.678255e-05), ('n02108422', 'bull_mastiff', 7.960046e-05), ('n02110806', 'basenji', 7.0177724e-05)]
