# %% [markdown]
# #  Model: Xception

# %% [markdown]
# Source Code for Xception: Trilogy Education Services © 2019
#
# Image Source: UnSplash

# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
# Load the Xception model
# https://keras.io/api/applications/xception/
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
# Default Image Size for Xception
image_size = (299, 299)

# %%
# Prediction function using Xception model
def predict(image_path):
    """Use Xception to label image"""
    
    # Loading image for the input dimensions that Xception was trained with
    img = image.load_img(image_path, target_size=image_size)
    
    # Preprocess image for model prediction (scaling and normalization for Xception)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    # Predictions
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3)[0])

# %%
image_path = os.path.join("Images", "image1.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02113023', 'Pembroke', 0.59329426), ('n02113186', 'Cardigan', 0.31151077), ('n02110806', 'basenji', 0.009258252)]

# %%
image_path = os.path.join("Images", "image2.jpeg")
predict(image_path)
# Out:
# Predicted: [('n04409515', 'tennis_ball', 0.14542551), ('n02102480', 'Sussex_spaniel', 0.09673437), ('n02102040', 'English_springer', 0.09512998)]

# %%
image_path = os.path.join("Images", "image3.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02510455', 'giant_panda', 0.85315037), ('n02447366', 'badger', 0.004475904), ('n02509815', 'lesser_panda', 0.0034920229)]

# %%
image_path = os.path.join("Images", "image4.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02342885', 'hamster', 0.85519296), ('n02364673', 'guinea_pig', 0.0096656205), ('n07714990', 'broccoli', 0.0054381094)]

# %%
image_path = os.path.join("Images", "image5.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02346627', 'porcupine', 0.97967666), ('n02138441', 'meerkat', 0.0008223876), ('n01872401', 'echidna', 0.00034844122)]

# %%
image_path = os.path.join("Images", "image6.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02101388', 'Brittany_spaniel', 0.12498847), ('n02099601', 'golden_retriever', 0.08582684), ('n02102480', 'Sussex_spaniel', 0.072842754)]

# %%
image_path = os.path.join("Images", "image7.jpeg")
predict(image_path)
# Out:
# Predicted: [('n01818515', 'macaw', 0.8819317), ('n01820546', 'lorikeet', 0.004630156), ('n01819313', 'sulphur-crested_cockatoo', 0.0015920374)]

# %%
image_path = os.path.join("Images", "image8.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02123045', 'tabby', 0.49432576), ('n02123159', 'tiger_cat', 0.23086765), ('n02124075', 'Egyptian_cat', 0.06610969)]

# %%
image_path = os.path.join("Images", "image9.jpeg")
predict(image_path)
# Out:
# Predicted: [('n01644373', 'tree_frog', 0.8877746), ('n01644900', 'tailed_frog', 0.053634893), ('n01629819', 'European_fire_salamander', 0.002415602)]

# %%
image_path = os.path.join("Images", "image10.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02108915', 'French_bulldog', 0.9983651), ('n02096585', 'Boston_bull', 0.0001763827), ('n02085620', 'Chihuahua', 3.2010335e-05)]
