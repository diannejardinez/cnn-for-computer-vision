# %% [markdown]
# #  Model: ResNet152

# %% [markdown]
# Image Source: UnSplash

# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import (ResNet152,
     preprocess_input, decode_predictions)

from keras import backend as K 
from keras.layers import Layer

# %%
# Load the ResNet152 model
# https://keras.io/api/applications/resnet/#resnet152-function
model = ResNet152(
        include_top=True,
        weights="imagenet",
        input_tensor=None,
        input_shape=None,
        pooling=None,
        classes=1000
)

# %%
# Image Size for ResNet152
image_size = (224, 224)

# %%
# Prediction function using ResNet152 model
def predict(image_path):
    """Use ResNet152 to label image"""
    
    # Loading image for the input dimensions that ResNet152 was trained with
    img = image.load_img(image_path, target_size=image_size)
    
    # Preprocess image for model prediction (scaling and normalization for ResNet152)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    # Predictions
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=5)[0])

# %%
image_path = os.path.join("Images", "image1.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02113023', 'Pembroke', 0.83518326), ('n02113186', 'Cardigan', 0.1630708), ('n02110806', 'basenji', 0.0013911121), ('n04409515', 'tennis_ball', 0.00012189019), ('n02115641', 'dingo', 7.953042e-05)]

# %%
image_path = os.path.join("Images", "image2.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02102318', 'cocker_spaniel', 0.64444727), ('n02101006', 'Gordon_setter', 0.1518101), ('n02099267', 'flat-coated_retriever', 0.06929776), ('n02102040', 'English_springer', 0.0641861), ('n02099429', 'curly-coated_retriever', 0.030793862)]

# %%
image_path = os.path.join("Images", "image3.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02510455', 'giant_panda', 0.99726796), ('n02447366', 'badger', 0.0009341936), ('n02509815', 'lesser_panda', 0.0005574735), ('n02134084', 'ice_bear', 0.00027068044), ('n02132136', 'brown_bear', 0.00022284513)]

# %%
image_path = os.path.join("Images", "image4.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02342885', 'hamster', 0.99954647), ('n02364673', 'guinea_pig', 0.00013643078), ('n07714990', 'broccoli', 0.00011204663), ('n03794056', 'mousetrap', 3.127019e-05), ('n02328150', 'Angora', 2.9162897e-05)]

# %%
image_path = os.path.join("Images", "image5.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02346627', 'porcupine', 0.98674774), ('n02138441', 'meerkat', 0.012242235), ('n02447366', 'badger', 0.00021083523), ('n02484975', 'guenon', 0.00017379838), ('n02137549', 'mongoose', 0.00015615571)]

# %%
image_path = os.path.join("Images", "image6.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02102480', 'Sussex_spaniel', 0.46350008), ('n02101388', 'Brittany_spaniel', 0.28524712), ('n02099601', 'golden_retriever', 0.08461306), ('n02099267', 'flat-coated_retriever', 0.059127428), ('n02099849', 'Chesapeake_Bay_retriever', 0.05154831)]

# %%
image_path = os.path.join("Images", "image7.jpeg")
predict(image_path)
# Out:
# Predicted: [('n01818515', 'macaw', 0.9999968), ('n01820546', 'lorikeet', 2.0865405e-06), ('n01819313', 'sulphur-crested_cockatoo', 1.0795417e-06), ('n01828970', 'bee_eater', 4.357886e-08), ('n01580077', 'jay', 1.3672452e-08)]

# %%
image_path = os.path.join("Images", "image8.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02123045', 'tabby', 0.54497564), ('n02124075', 'Egyptian_cat', 0.2895509), ('n02123159', 'tiger_cat', 0.14693917), ('n02127052', 'lynx', 0.0070617823), ('n03657121', 'lens_cap', 0.0023481518)]

# %%
image_path = os.path.join("Images", "image9.jpeg")
predict(image_path)
# Out:
# Predicted: [('n01644373', 'tree_frog', 0.99070436), ('n01644900', 'tailed_frog', 0.0066543133), ('n01820546', 'lorikeet', 0.0005471092), ('n01641577', 'bullfrog', 0.00021835533), ('n02259212', 'leafhopper', 0.0001849404)]

# %%
image_path = os.path.join("Images", "image10.jpeg")
predict(image_path)
# Out:
# Predicted: [('n02108915', 'French_bulldog', 0.9995352), ('n02096585', 'Boston_bull', 0.00027969285), ('n02085620', 'Chihuahua', 6.0808827e-05), ('n02110958', 'pug', 3.1562042e-05), ('n04409515', 'tennis_ball', 2.7650565e-05)]
